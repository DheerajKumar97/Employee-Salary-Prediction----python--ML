# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_columns = 30

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv("E:/Downlload/train.csv")
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# #  Data Visualization

# %%
def show_hist(x):
    plt.rcParams["figure.figsize"] = 15,18
    x.hist()
show_hist(df)

# %%
def Show_DisPlot(x):
    plt.style.use('fivethirtyeight')
    plt.figure(figsize=(12,7))
    sns.distplot(x, bins = 25)

# %%
Show_DisPlot(df.User_ID)

# %%
Show_DisPlot(df.Occupation)

# %%
Show_DisPlot(df.Marital_Status)

# %%
Show_DisPlot(df.Product_Category_1)

# %%
Show_DisPlot(df.Purchase)

# %%
def Show_CountPlot(x):
    sns.countplot(x)

# %%
plt.figure(figsize=(6,6))
Show_CountPlot(df.Gender)

# %%
plt.figure(figsize=(6,6))
Show_CountPlot(df.Age)

# %%
plt.figure(figsize=(6,6))
Show_CountPlot(df.City_Category)

# %%
plt.figure(figsize=(6,6))
Show_CountPlot(df.Marital_Status)

# %%
def Show_Hist(x,y):
    x.hist(bins=50, figsize=(12,8), by=y)

# %%
Show_Hist(df.Gender,df.City_Category)

# %%
Show_Hist(df.City_Category,df.Marital_Status)

# %%
Show_Hist(df.Gender,df.Age)

# %%
Show_Hist(df.Gender,df.Marital_Status)

# %%
Show_Hist(df.Age,df.Marital_Status)

# %%
def Show_BoxPlot(X,Y,Z):
    fig_dims = (18, 5)
    fig, ax = plt.subplots(figsize=fig_dims)
    sns.boxplot(x=X, y=Y, hue=Z,ax=ax)

# %%
Show_BoxPlot(df.Age, df.Marital_Status, df.Gender)

# %%
Show_BoxPlot(df.Gender, df.Marital_Status, df.City_Category)

# %%
Show_BoxPlot(df.Gender, df.Marital_Status, df.Stay_In_Current_City_Years)

# %%
def Show_Bar_Plot(x,y,z,data):
    fig_dims = (18, 5)
    fig, ax = plt.subplots(figsize=fig_dims)
    sns.barplot(x=x, y=y, hue=z,
                        data=data, palette="muted",ax=ax)

# %%
def Show_Bar_Plot1(x,y,data):
    fig_dims = (18, 5)
    fig, ax = plt.subplots(figsize=fig_dims)
    sns.barplot(x=x, y=y,data=data, palette="muted",ax=ax)

# %%
Show_Bar_Plot1(df.Gender,df.Marital_Status,df)

# %%
Show_Bar_Plot1(df.Age,df.Marital_Status,df)

# %%
Show_Bar_Plot1(df.Gender,df.Product_Category_1,df)

# %%
Show_Bar_Plot1(df.Gender,df.Occupation,df)

# %%
Show_Bar_Plot(df.Gender,df.Marital_Status,df.Stay_In_Current_City_Years,df)

# %%
def Show_Violin_Plot(x,y,data):
    fig_dims = (18, 5)
    fig, ax = plt.subplots(figsize=fig_dims)
    sns.violinplot(x=x,y=y,data=data,ax=ax)

# %%
Show_Violin_Plot(df.Marital_Status,df.Gender,df)

# %%
Show_Violin_Plot(df.Occupation,df.Gender,df)

# %%
Show_Violin_Plot(df.Occupation,df.Stay_In_Current_City_Years,df)

# %%
Show_Violin_Plot(df.Occupation,df.Age,df)

# %%
Show_Violin_Plot(df.Occupation,df.Gender,df)

# %%
def Show_HeatMap(x):
    f,ax = plt.subplots(figsize=(15, 15))
    sns.heatmap(x.corr(),annot=True,ax=ax);

# %%
Show_HeatMap(df)

# %% [markdown]
# # Data Preprocessing and Feature Engineering

# %%
df.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# ...

# %%
cat_var = [var for var in df.columns if df[var].dtypes =="object"]
cat_var = df[cat_var]
cat_var
# Out:
#        Product_ID Gender    Age City_Category Stay_In_Current_City_Years
# 0       P00069042      F   0-17             A                          2
# 1       P00248942      F   0-17             A                          2
# 2       P00087842      F   0-17             A                          2
# 3       P00085442      F   0-17             A                          2
# 4       P00285442      M    55+             C                         4+
# ...           ...    ...    ...           ...                        ...
# 550063  P00372445      M  51-55             B                          1
# 550064  P00375436      F  26-35             C                          3
# 550065  P00375436      F  26-35             B                         4+
# 550066  P00375436      F    55+             C                          2
# 550067  P00371644      F  46-50             B                         4+
#
# [550068 rows x 5 columns]

# %%
cat_var.isna().sum()
# Out:
# Product_ID                    0
# Gender                        0
# Age                           0
# City_Category                 0
# Stay_In_Current_City_Years    0
# dtype: int64

# %%
cat_var['Age'].unique()
# Out:
# array(['1', '2', '3', '4', '5', '6', '7'], dtype=object)

# %%
cat_var['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
cat_var['Stay_In_Current_City_Years'].unique()
# Out:
# array([0], dtype=int64)

# %%
cat_var
# Out:
#        Product_ID Gender Age City_Category Stay_In_Current_City_Years
# 0       P00069042      F   1             A                          2
# 1       P00248942      F   1             A                          2
# 2       P00087842      F   1             A                          2
# 3       P00085442      F   1             A                          2
# 4       P00285442      M   2             C                         4+
# ...           ...    ...  ..           ...                        ...
# 550063  P00372445      M   5             B                          1
# 550064  P00375436      F   3             C                          3
# 550065  P00375436      F   3             B                         4+
# 550066  P00375436      F   2             C                          2
# 550067  P00371644      F   4             B                         4+
#
# [550068 rows x 5 columns]

# %%
def encode_Age(Age):
    if Age == "0-17":
        return 1
    elif Age == "55+":
        return 2
    elif Age == "26-35":
        return 3
    elif Age == "46-50":
        return 4
    elif Age == "51-55":
        return 5
    elif Age == "36-45":
        return 6
    elif Age == "18-25":
        return 7
    else:
        return 0
cat_var['Age'] = cat_var['Age'].apply(encode_Age)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def encode_Stay_In_Current_City_Years(Stay_In_Current_City_Years):
    if Stay_In_Current_City_Years == "4+":
        return 4
    elif Stay_In_Current_City_Years == "1":
        return 2
    elif Stay_In_Current_City_Years == "2":
        return 3
    elif Stay_In_Current_City_Years == "3":
        return 4
cat_var['Stay_In_Current_City_Years'] = cat_var['Stay_In_Current_City_Years'].apply(encode_Stay_In_Current_City_Years)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
cat_var
# Out:
#        Product_ID  Gender Age  City_Category Stay_In_Current_City_Years
# 0       P00069042       1   1              1                          3
# 1       P00248942       1   1              1                          3
# 2       P00087842       1   1              1                          3
# 3       P00085442       1   1              1                          3
# 4       P00285442       0   2              3                          4
# ...           ...     ...  ..            ...                        ...
# 550063  P00372445       0   5              2                          2
# 550064  P00375436       1   3              3                          4
# 550065  P00375436       1   3              2                          4
# 550066  P00375436       1   2              3                          3
# 550067  P00371644       1   4              2                          4
#
# [550068 rows x 5 columns]

# %%
cat_var['Gender'] = pd.get_dummies(cat_var['Gender'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def encode_City_Category(City_Category):
    if City_Category == "A":
        return 1
    elif City_Category == "B":
        return 2
    elif City_Category == "C":
        return 3
cat_var['City_Category'] = cat_var['City_Category'].apply(encode_City_Category)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cat_var['Purchase'] = df['Purchase']
cat_var
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Product_ID  Gender  Age  City_Category  Stay_In_Current_City_Years  \
# 0       P00069042       1    1              1                         3.0
# 1       P00248942       1    1              1                         3.0
# 2       P00087842       1    1              1                         3.0
# 3       P00085442       1    1              1                         3.0
# 4       P00285442       0    2              3                         4.0
# ...           ...     ...  ...            ...                         ...
# ...

# %%
mean_encode = cat_var.groupby('Product_ID')['Purchase'].mean()

# %%
cat_var.loc[:,'encoded_id'] = cat_var.Product_ID.map(mean_encode)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
mean = cat_var['Purchase'].mean()
agg =  cat_var.groupby('Product_ID')['Purchase'].agg(['count','mean'])
counts = agg['count']
means =agg['mean']
weight =100

# %%
smooth = (counts * means + weight * means) / (counts + weight)
smooth
# Out:
# Product_ID
# P00000142    11143.642361
# P00000242    10551.851064
# P00000342     5313.422131
# P00000442     4795.358696
# P00000542     5417.530201
#                  ...
# P0099442     14351.915000
# P0099642      6439.230769
# P0099742      7872.603175
# P0099842      7228.549020
# P0099942      5572.785714
# Length: 3631, dtype: float64

# %%
cat_var.loc[:,'encoded_id'] = cat_var.Product_ID.map(smooth)

# %%
cat_var =cat_var.drop(['Product_ID'],axis=1)

# %%
cat_var
# Out:
#         Gender  Age  City_Category  Stay_In_Current_City_Years  Purchase  \
# 0            1    1              1                         3.0      8370
# 1            1    1              1                         3.0     15200
# 2            1    1              1                         3.0      1422
# 3            1    1              1                         3.0      1057
# 4            0    2              3                         4.0      7969
# ...        ...  ...            ...                         ...       ...
# 550063       0    5              2                         2.0       368
# 550064       1    3              3                         4.0       371
# 550065       1    3              2                         4.0       137
# 550066       1    2              3                         3.0       365
# 550067       1    4              2                         4.0       490
#
#           encoded_id
# 0       11870.863436
# 1       16304.030981
# 2        1237.892157
# ...

# %%
num_var = [var for var in df.columns if df[var].dtypes !="object"]
num_var = df[num_var]
num_var
# Out:
#         User_ID  Occupation  Marital_Status  Product_Category_1  \
# 0       1000001          10               0                   3
# 1       1000001          10               0                   1
# 2       1000001          10               0                  12
# 3       1000001          10               0                  12
# 4       1000002          16               0                   8
# ...         ...         ...             ...                 ...
# 550063  1006033          13               1                  20
# 550064  1006035           1               0                  20
# 550065  1006036          15               1                  20
# 550066  1006038           1               0                  20
# 550067  1006039           0               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# ...

# %%
#num_var = num_var.drop(['Purchase'],axis=1)
num_var = num_var.drop(['Product_Category_2'],axis=1)
num_var = num_var.drop(['Product_Category_3'],axis=1)
num_var
# Out:
#         User_ID  Occupation  Marital_Status  Product_Category_1
# 0       1000001          10               0                   3
# 1       1000001          10               0                   1
# 2       1000001          10               0                  12
# 3       1000001          10               0                  12
# 4       1000002          16               0                   8
# ...         ...         ...             ...                 ...
# 550063  1006033          13               1                  20
# 550064  1006035           1               0                  20
# 550065  1006036          15               1                  20
# 550066  1006038           1               0                  20
# 550067  1006039           0               1                  20
#
# [550068 rows x 4 columns]

# %%
df_new = pd.concat([num_var,cat_var],axis=1)
df_new
# Out:
#         User_ID  Occupation  Marital_Status  Product_Category_1  Gender  Age  \
# 0       1000001          10               0                   3       1    1
# 1       1000001          10               0                   1       1    1
# 2       1000001          10               0                  12       1    1
# 3       1000001          10               0                  12       1    1
# 4       1000002          16               0                   8       0    2
# ...         ...         ...             ...                 ...     ...  ...
# 550063  1006033          13               1                  20       0    5
# 550064  1006035           1               0                  20       1    3
# 550065  1006036          15               1                  20       1    3
# 550066  1006038           1               0                  20       1    2
# 550067  1006039           0               1                  20       1    4
#
# ...

# %%
df_new = df_new.apply(lambda x:(x.astype(float) - min(x))/(max(x)-min(x)), axis = 0)
df_new
# Out:
#          User_ID  Occupation  Marital_Status  Product_Category_1  Gender  \
# 0       0.000000        0.50             0.0            0.105263     1.0
# 1       0.000000        0.50             0.0            0.000000     1.0
# 2       0.000000        0.50             0.0            0.578947     1.0
# 3       0.000000        0.50             0.0            0.578947     1.0
# 4       0.000166        0.80             0.0            0.368421     0.0
# ...          ...         ...             ...                 ...     ...
# 550063  0.998841        0.65             1.0            1.000000     0.0
# 550064  0.999172        0.05             0.0            1.000000     1.0
# 550065  0.999338        0.75             1.0            1.000000     1.0
# 550066  0.999669        0.05             0.0            1.000000     1.0
# 550067  0.999834        0.00             1.0            1.000000     1.0
#
#              Age  City_Category  Stay_In_Current_City_Years  Purchase  \
# ...

# %%
df_new.isna().sum()
# Out:
# User_ID                       0
# Occupation                    0
# Marital_Status                0
# Product_Category_1            0
# Gender                        0
# Age                           0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Purchase                      0
# encoded_id                    0
# dtype: int64

# %%
df_new['Stay_In_Current_City_Years'] = df_new['Stay_In_Current_City_Years'].fillna(df_new['Stay_In_Current_City_Years'].mode()[0])

# %%
x = df_new.drop(['Purchase'],axis=1)
x = df_new.drop(['Occupation'],axis=1)
x = df_new.drop(['Stay_In_Current_City_Years'],axis=1)
y = df_new['Purchase']

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=40)

# %%
x_train.shape
# Out:
# (385047, 9)

# %%
import statsmodels.api as sm
model2 =sm.OLS(y_train,x_train).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               Purchase   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          5.571e+34
# Date:                Sun, 26 Apr 2020   Prob (F-statistic):                        0.00
# Time:                        18:02:42   Log-Likelihood:                      1.3120e+07
# No. Observations:              385047   AIC:                                 -2.624e+07
# Df Residuals:                  385038   BIC:                                 -2.624e+07
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Linear Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
lr = LinearRegression()
LR =lr.fit(x_train,y_train)

# %%
LR_Pred = lr.predict(x_test)

# %%
LR_predicted = pd.DataFrame(LR_Pred)
LR_predicted = LR_predicted.reset_index(drop=True)

# %%
Actuall = pd.DataFrame(y_test)
Actuall = Actuall.reset_index(drop=True)

# %%
print("Linear Regression's Actual_vs_predicted")
LR_Actual_vs_predicted = pd.concat([Actual,LR_predicted],axis=1)
LR_Actual_vs_predicted = LR_Actual_vs_predicted.rename(columns={'Purchase':'Actual',0:'Predicted'})
LR_Actual_vs_predicted
# Out:
# Linear Regression's Actual_vs_predicted
#           Actual  Predicted
# 0       0.646165   0.646165
# 1       0.223642   0.223642
# 2       0.406531   0.406531
# 3       0.030899   0.030899
# 4       0.649088   0.649088
# ...          ...        ...
# 165016  0.192993   0.192993
# 165017  0.676688   0.676688
# 165018  0.245563   0.245563
# 165019  0.297298   0.297298
# 165020  0.686751   0.686751
#
# [165021 rows x 2 columns]

# %%
LR_RMSE = np.sqrt(metrics.mean_squared_error(y_test,LR_Pred))
LR_RMSE
# Out:
# 4.646541863981831e-16

# %%
LR_r2_score = r2_score(y_test,LR_Pred)
LR_r2_score
# Out:
# 1.0

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=1000,random_state=3)
reg=regressor.fit(x_train,y_train)

# %%
rf_y_pred=regressor.predict(x_test)

# %%
predicted = pd.DataFrame(rf_y_pred)
predicted = predicted.reset_index(drop=True)

# %%
Actual = pd.DataFrame(y_test)
Actual = Actual.reset_index(drop=True)

# %%
print("Random Forest's Actual_vs_predicted")
Actual_vs_predicted = pd.concat([Actual,predicted],axis=1)
Actual_vs_predicted = Actual_vs_predicted.rename(columns={'Purchase':'Actual',0:'Predicted'})
Actual_vs_predicted
# Out:
# Random Forest's Actual_vs_predicted
#           Actual  Predicted
# 0       0.646165   0.646233
# 1       0.223642   0.223393
# 2       0.406531   0.406359
# 3       0.030899   0.030732
# 4       0.649088   0.649223
# ...          ...        ...
# 165016  0.192993   0.192836
# 165017  0.676688   0.676628
# 165018  0.245563   0.245558
# 165019  0.297298   0.297475
# 165020  0.686751   0.686791
#
# [165021 rows x 2 columns]

# %%
from sklearn import metrics
rf_RMSE = np.sqrt(metrics.mean_squared_error(y_test,rf_y_pred))
rf_RMSE
# Out:
# 0.00016052594262053717

# %%
from sklearn.metrics import r2_score
rf_r2_score = r2_score(y_test,rf_y_pred)
rf_r2_score
# Out:
# 0.9999994147215058

# %% [markdown]
# # XGBoost Model

# %%
from xgboost import XGBRegressor
xg_reg =XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.2, max_depth = 6, 
                          alpha = 7, n_estimators = 1000)
xg_reg.fit(x_train,y_train)
# Out:
# [18:52:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(alpha=7, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.2, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
preds = xg_reg.predict(x_test)

# %%
XGB_predicted = pd.DataFrame(preds)
XGB_predicted = XGB_predicted.reset_index(drop=True)

# %%
Actuall = pd.DataFrame(y_test)
Actuall = Actuall.reset_index(drop=True)

# %%
print("XGboost's Actual_vs_predicted")
XGB_Actual_vs_predicted = pd.concat([Actuall,XGB_predicted],axis=1)
XGB_Actual_vs_predicted = XGB_Actual_vs_predicted.rename(columns={'Purchase':'Actual',0:'Predicted'})
XGB_Actual_vs_predicted
# Out:
# XGboost's Actual_vs_predicted
#           Actual  Predicted
# 0       0.646165   0.647426
# 1       0.223642   0.226696
# 2       0.406531   0.409304
# 3       0.030899   0.029908
# 4       0.649088   0.648571
# ...          ...        ...
# 165016  0.192993   0.191490
# 165017  0.676688   0.680523
# 165018  0.245563   0.246317
# 165019  0.297298   0.299436
# 165020  0.686751   0.693143
#
# [165021 rows x 2 columns]

# %%
from sklearn import metrics
XGb_RMSE = np.sqrt(metrics.mean_squared_error(y_test,preds))
XGb_RMSE
# Out:
# 0.002932968439733692

# %%
from sklearn.metrics import r2_score
XGb_r2_score = r2_score(y_test,preds)
XGb_r2_score
# Out:
# 0.9998046169483773

# %% [markdown]
# # KNN Model

# %%
from sklearn.neighbors import KNeighborsRegressor
clf = KNeighborsRegressor(n_neighbors = 1,  weights = 'distance', p=1)
reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=3, verbose=0, warm_start=False)

# %%
KNN_pred = reg.predict(x_test)

# %%
KNN_predicted = pd.DataFrame(preds)
KNN_predicted = KNN_predicted.reset_index(drop=True)

# %%
Actuall = pd.DataFrame(y_test)
Actuall = Actuall.reset_index(drop=True)

# %%
print("KNN's Actual_vs_predicted")
KNN_Actual_vs_predicted = pd.concat([Actuall,KNN_predicted],axis=1)
KNN_Actual_vs_predicted = KNN_Actual_vs_predicted.rename(columns={'Purchase':'Actual',0:'Predicted'})
KNN_Actual_vs_predicted
# Out:
# KNN's Actual_vs_predicted
#           Actual  Predicted
# 0       0.646165   0.647426
# 1       0.223642   0.226696
# 2       0.406531   0.409304
# 3       0.030899   0.029908
# 4       0.649088   0.648571
# ...          ...        ...
# 165016  0.192993   0.191490
# 165017  0.676688   0.680523
# 165018  0.245563   0.246317
# 165019  0.297298   0.299436
# 165020  0.686751   0.693143
#
# [165021 rows x 2 columns]

# %%
from sklearn import metrics
KNN_RMSE = np.sqrt(metrics.mean_squared_error(y_test,KNN_pred))
KNN_RMSE
# Out:
# 0.00016052594262053717

# %%
from sklearn.metrics import r2_score
KNN_r2_score = r2_score(y_test,KNN_pred)
KNN_r2_score
# Out:
# 0.9999994147215058

# %% [markdown]
# # ADA Boost Model

# %%
from sklearn.ensemble import AdaBoostRegressor
Ada_reg =AdaBoostRegressor(learning_rate = 0.10,base_estimator =None ,loss = 'linear',n_estimators = 10000)
Ada_reg.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='linear',
#                   n_estimators=10000, random_state=None)

# %%
Ada_pred = Ada_reg.predict(x_test)

# %%
ADA_BOOST_predicted = pd.DataFrame(preds)
ADA_BOOST_predicted = ADA_BOOST_predicted.reset_index(drop=True)

# %%
Actuall = pd.DataFrame(y_test)
Actuall = Actuall.reset_index(drop=True)

# %%
print("ADA_BOOST's Actual_vs_predicted")
ADA_BOOST_Actual_vs_predicted = pd.concat([Actuall,ADA_BOOST_predicted],axis=1)
ADA_BOOST_Actual_vs_predicted = ADA_BOOST_Actual_vs_predicted.rename(columns={'Purchase':'Actual',0:'Predicted'})
ADA_BOOST_Actual_vs_predicted
# Out:
# ADA_BOOST's Actual_vs_predicted
#           Actual  Predicted
# 0       0.646165   0.647426
# 1       0.223642   0.226696
# 2       0.406531   0.409304
# 3       0.030899   0.029908
# 4       0.649088   0.648571
# ...          ...        ...
# 165016  0.192993   0.191490
# 165017  0.676688   0.680523
# 165018  0.245563   0.246317
# 165019  0.297298   0.299436
# 165020  0.686751   0.693143
#
# [165021 rows x 2 columns]

# %%
from sklearn import metrics
Ada_RMSE = np.sqrt(metrics.mean_squared_error(y_test,Ada_pred))
Ada_RMSE
# Out:
# 0.014472540579274282

# %%
from sklearn.metrics import r2_score
Ada_r2_score = r2_score(y_test,Ada_pred)
Ada_r2_score
# Out:
# 0.995242687715411

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
Dtree_reg = DecisionTreeRegressor()
clf =Dtree_reg.fit(x_train,y_train)

# %%
Dtree_pred = Dtree_reg.predict(x_test)

# %%
from sklearn import metrics
Dtree_RMSE = np.sqrt(metrics.mean_squared_error(y_test,Dtree_pred))
Dtree_RMSE
# Out:
# 0.00024362453136972376

# %%
from sklearn.metrics import r2_score
Dtree_r2_score = r2_score(y_test,Dtree_pred)
Dtree_r2_score
# Out:
# 0.9999986519247283

# %%
Best_Model ={'Model':['LinearRegression','RandomForestRegressor', 'XGBoost Regressor','KNN Regressor','AdaBoost Regressor','Decision_Tree Regressor'],
        'R2_Score':[LR_r2_score,rf_r2_score,XGb_r2_score,KNN_r2_score,Ada_r2_score,Dtree_r2_score],'RMSE':[LR_RMSE,rf_RMSE,XGb_RMSE,KNN_RMSE,Ada_RMSE,Dtree_RMSE]}
Best_Model =pd.DataFrame(Best_Model)
Best_Model=Best_Model.set_index('Model')
Best_Model
# Out:
#                          R2_Score          RMSE
# Model
# LinearRegression         1.000000  4.646542e-16
# RandomForestRegressor    0.999999  1.605259e-04
# XGBoost Regressor        0.999805  2.932968e-03
# KNN Regressor            0.999999  1.605259e-04
# AdaBoost Regressor       0.995243  1.447254e-02
# Decision_Tree Regressor  0.999999  2.436245e-04
